# %% [markdown]
# # Data Visualization Using Python
#
# **Data Visualization** adalah suatu proses merepresentasikan data dan informasi dengan grafis melalui elemen visual seperti simple text, bagan, grafik, dan peta setelah melalui preprocessing data terlebih dahulu. Bagi seorang analyst, kemampuan berkomunikasi sangat diperlukan, dan data visualisasi adalah jempatan yang dapat menghubungkan analyst dengan pendengar/pembaca.
# <br>
# <br>
# Python memiliki library yang dapat membantu anda dalam memvisualisasikan data. Library yang paling banyak digunakan saat ini untuk visualisasi adalah matplotlib dan seaborn. Perbedaan dari keduanya adalah dari tampilan visualisasi. Dengan seaborn anda dapat melakukan mix and match visual menjadi lebih bagus dan indah. Untuk lebih lengkapnya anda dapat mempelajari mengenai masing-masing library melalui link dibawah ini.
# <br>
# **Matplotlib** : https://matplotlib.org/ <br>
# **Seaborn** : https://seaborn.pydata.org/
# <br>
#
# Adapun untuk membuat visualisasi data yang lebih dinamis dan tampilannya lebih menarik, Anda dapat mempelajari library <br>
# **Plotly**  : https://plotly.com/python/

# %% [markdown]
# ## Mengkoneksikan Colab dengan Gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Import Packages

# %%
# !pip install plotly==4.14.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 85.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ...

# %%
# Import package
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %% [markdown]
# ## Setting Path

# %%
# Load the data
# path_data = os.getcwd()+'/sample_data/'
# path_data = "/content/gdrive/MyDrive/Narasio/meet 16/Data"
path_data = '/content/gdrive/My Drive/PKKM KA/Day 1/Data Visualization/Dataset/'
# Check Directory
os.listdir(path_data)
# os.listdir(path)
# Out:
# ['avocado.csv', 'geolocation.csv', 'ride_sharing_new.csv', 'titanic.csv']

# %% [markdown]
# ## Menggunakan Pandas dengan Seaborn

# %%
# Membaca / import data .csv
# df = pd.read_csv(path_data + 'avocado (1).csv')
df = pd.read_csv(path_data + 'avocado.csv')
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  12/27/2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  12/20/2015          1.35      54876.98   674.28   44638.81   58.33
# 2  12/13/2015          0.93     118220.22   794.70  109149.67  130.50
# 3   12/6/2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  11/29/2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# Menampilkan tahun dataframe
print(df["year"].unique())
print(df["year"].value_counts())
# Out:
# [2015 2016 2017 2018]
# year
# 2017    5616
# 2016    5512
# 2015    5511
# 2018    1272
# Name: count, dtype: int64

# %%
# Menampilkan list nama-nama kolom
list(df.columns)
# Out:
# ['Date',
#  'AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
# Mengetahui informasi kelengkapan dan tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17911 entries, 0 to 17910
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          17911 non-null  object
#  1   AveragePrice  17911 non-null  float64
#  2   Total Volume  17911 non-null  float64
#  3   4046          17911 non-null  float64
#  4   4225          17911 non-null  float64
#  5   4770          17911 non-null  float64
#  6   Total Bags    17911 non-null  float64
#  7   Small Bags    17911 non-null  float64
#  8   Large Bags    17911 non-null  float64
#  9   XLarge Bags   17911 non-null  float64
#  10  type          17911 non-null  object
#  11  year          17911 non-null  int64
#  12  region        17911 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Visualisasi Data

# %% [markdown]
# #### Bar Chart - Count Plot

# %% [markdown]
# Bar Chart digunakan untuk menunjukkan frekuensi atau nilai kuantitatif lainnya seperti rata-rata, jumlah, persentase dari data kategorik.

# %%
len(df["region"].unique())
# Out:
# 53

# %%
test=df['region'].value_counts()
plt.figure(figsize=(20,9))
sns.barplot(x=test.index,y=test.values, palette="flare")
# Out:
# <Axes: >

# %%
# visualisasi banyaknya pencatatan tiap tahun
g = sns.catplot(x="region", kind="count", palette="flare", data=df)
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(20,8)
#plt.show()

# %% [markdown]
# Pencatatan data retail pada masing-masing region tidak jauh berbeda

# %% [markdown]
# #### Box Plot

# %% [markdown]
# Box plot digunakan untuk mengetahu penyebaran data. Ada banyak informasi yang kita dapatkan dari box plot yaitu nilai minimum, nilai maksimum, quartil pertama, median (quartil kedua), kuartil ketiga, dan outliers.

# %%
# Visualisasi menggunakan seaborn
# visualisasi sebaran total volume setiap tahun berdasarkan type
g = sns.catplot(x="type",
            y="Total Volume", hue="year", palette="flare", kind="box", data=df)
g.fig.set_size_inches(20,8)
plt.show()

# %%
# Visualisasi menggunakan plotly
fig = px.box(df, x="type", y="Total Volume", color="year")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > Tipe konvensional memiliki lebih banyak outliers dibandingkan tipe organik. Terlihat nilai median tidak jauh berbeda setiap tahunnya pada masing-masing tipe, sedangkan nilai median pada conventional dan organic terlihat ada perbedaan.

# %% [markdown]
# #### Scatterplot

# %% [markdown]
# Scatterplot digunakan ketika ingin melihat relasi antara 2 variabel dan dari 2 variabel tersebut dapat diketahui variabel mana yang memiliki nilai yang lebih besar.

# %%
# visualisasi hubungan variabel AveragePrice dan Total Volume
sns.scatterplot(x="AveragePrice",
                y="Total Volume",
                data = df)
plt.savefig('testplot.png')
# plt.show()

# %%
# memberikan warna yang berbeda untuk masing-masing type
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x="AveragePrice",
                y="Total Volume",
                data = df,
                hue = 'type')

plt.show()

# %%
# mengurutkan label type
plt.figure(figsize=(15,8))
ax = sns.scatterplot(x="AveragePrice",
                y="Total Volume",
                data = df,
                hue = 'type',
                hue_order=["organic","conventional"])
plt.show()

# %%
# custom warna untuk setiap item di variabel type
hue_colors = {"organic":'green',
              "conventional":"red"}
sns.scatterplot(x="AveragePrice",
                y="Total Volume",
                data = df,
                hue = 'type',
                palette=hue_colors)
plt.show()

# %%
# Visualisasi menggunakan plotly
fig = px.scatter(data_frame=df, x="AveragePrice", y="Total Volume", color="type", color_discrete_sequence=['red', 'green'])
fig.update_traces(marker=dict(size=10,
                              line=dict(width=1,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > Total volume conventional lebih tinggi daripada total volume organik. Selain itu, rata-rata harga tipe organic tidak berhubungan linier terhadap total volume, semakin tinggi rata-rata harga tipe organic tidak menjadikan total volume semakin tinggi atau semakin rendah. Berbeda dengan tipe organic, rata-rata harga tipe convensional tampak mempengaruhi total volume.

# %% [markdown]
# ### Line plot

# %% [markdown]
# Line plot digunakan untuk melihat pergerakan data yang bernilai kontinu dari waktu ke waktu sehingga dapat dilihat juga trend-nya.

# %%
# visualisasi line plot dengan default komponen
# mengurutkan label type
plt.figure(figsize=(15,8))
ax = sns.lineplot(data=df, x="Date", y="AveragePrice")
plt.xticks(rotation=90)
plt.show()

# %%
df[['Date']].dtypes
# Out:
# Date    object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[['Date']].dtypes
# Out:
# Date    datetime64[ns]
# dtype: object

# %%
# visualisasi line chart dengan tanggal terlihat jelas di sumbu horizontal
g=sns.relplot(x="Date", y="AveragePrice", kind="line",data=df, height=3)
g.fig.set_size_inches(20,8)
# g.set_xticklabels(rotation=90)

# %%
plt.figure(figsize=(20,9))
g1=df.groupby("Date")["AveragePrice"].mean()
g=sns.lineplot(x=g1.index, y=g1.values)

# %%
# Visualisasi menggunakan Plotly
data = df.groupby('Date')['AveragePrice'].mean()
fig = px.line(
    x = data.index,
    y = data.values,
    title = 'Time Series with Range Slider and Selectors',
    labels = {'y':'Average Price', 'x': 'Date'})

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > Pada setiap tahunnya, puncak harga tertinggi berada di akhir tahun dan kembali turun pada awal tahun. Rata-rata harga alpukat dari tahun 2015 hingga 2018 menunjukkan trend naik.

# %% [markdown]
# ### Stacked Bar Chart

# %% [markdown]
# Stacked Bar Chart digunakan untuk membandingkan banyak item dari kategori yang berbeda dan menunjukkan komposisi setiap item yang dibandingkan.

# %%
# Grouping total small bags, large bags, dan xlarge bags berdasarkan type
data_group=df.groupby('type')[['Small Bags', 'Large Bags', 'XLarge Bags']].sum()
data_group.reset_index(inplace=True)

# %%
data_group
# Out:
#            type    Small Bags    Large Bags  XLarge Bags
# 0  conventional  1.981154e+09  5.771905e+08  35226891.85
# 1       organic  1.001559e+08  4.084097e+07      7054.94

# %%
#data_group.iloc[1,1:] = data_group.iloc[1,1:]/data_group.iloc[1,1:].max()
#data_group

# %%
# plot total small bags, large bags, dan xlarge bags pada masing-masing tipe
data_group.plot(kind = 'bar',figsize = (15,10), stacked = True, x='type')
# Out:
# <Axes: xlabel='type'>

# %%
# Visualisasi menggunakan Plotly
fig = px.bar(data_group, x="type", y=["Small Bags", "Large Bags", "XLarge Bags"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > komposisi convensional di ketiga item (small bags, large bags, xlarge bags) lebih besar dibanding organic

# %% [markdown]
# ### Pareto Chart

# %% [markdown]
# Pareto chart menunjukkan nilai kuantitatif dari data kategorik dengan menampilkannya secara terurut dari nilai tertinggi ke terendah. Selain itu juga menunjukkan persentase atau nilai kumulatif dari nilai kuantitatifnya.

# %%
# menghitung rata-rata harga setiap region
data_group_cat=df.groupby('region')['AveragePrice'].mean()

# %%
data_group_cat
# Out:
# region
# Albany                 1.561036
# Atlanta                1.337959
# BaltimoreWashington    1.534231
# Boise                  1.348136
# Boston                 1.530888
# BuffaloRochester       1.516834
# California             1.395325
# Charlotte              1.606036
# Chicago                1.556775
# CincinnatiDayton       1.209201
# Columbus               1.252781
# DallasFtWorth          1.085592
# Denver                 1.218580
# Detroit                1.276095
# GrandRapids            1.505000
# GreatLakes             1.338550
# HarrisburgScranton     1.513284
# HartfordSpringfield    1.818639
# Houston                1.047929
# Indianapolis           1.313994
# Jacksonville           1.510947
# LasVegas               1.380917
# LosAngeles             1.216006
# Louisville             1.286686
# MiamiFtLauderdale      1.428491
# Midsouth               1.404763
# Nashville              1.212101
# NewOrleansMobile       1.304793
# NewYork                1.727574
# ...

# %%
df_data_group_cat = data_group_cat.reset_index()
df_data_group_cat
# Out:
#                  region  AveragePrice
# 0                Albany      1.561036
# 1               Atlanta      1.337959
# 2   BaltimoreWashington      1.534231
# 3                 Boise      1.348136
# 4                Boston      1.530888
# 5      BuffaloRochester      1.516834
# 6            California      1.395325
# 7             Charlotte      1.606036
# 8               Chicago      1.556775
# 9      CincinnatiDayton      1.209201
# 10             Columbus      1.252781
# 11        DallasFtWorth      1.085592
# 12               Denver      1.218580
# 13              Detroit      1.276095
# 14          GrandRapids      1.505000
# 15           GreatLakes      1.338550
# 16   HarrisburgScranton      1.513284
# 17  HartfordSpringfield      1.818639
# 18              Houston      1.047929
# 19         Indianapolis      1.313994
# 20         Jacksonville      1.510947
# 21             LasVegas      1.380917
# 22           LosAngeles      1.216006
# 23           Louisville      1.286686
# ...

# %%
# menghitung persentase kumulatif dari AveragePrice
total_AveragePrice = df_data_group_cat.AveragePrice.sum()
df_data_group_cat['percentage_AveragePrice'] = df_data_group_cat.AveragePrice/total_AveragePrice
df_data_group_cat = df_data_group_cat.sort_values('percentage_AveragePrice', ascending = False)
df_data_group_cat['cumsum_pct'] = df_data_group_cat.percentage_AveragePrice.cumsum()
df_data_group_cat.index = df_data_group_cat.region
# df_data_group_cat = df_data_group_cat[df_data_group_cat.cumsum_pct <= 0.98] # untuk memfilter 98% averageprice yang ingin ditampilkan
df_data_group_cat = df_data_group_cat
df_data_group_cat.head()
# Out:
#                                   region  AveragePrice  \
# region
# HartfordSpringfield  HartfordSpringfield      1.818639
# SanFrancisco                SanFrancisco      1.804201
# NewYork                          NewYork      1.727574
# Philadelphia                Philadelphia      1.632130
# Sacramento                    Sacramento      1.621568
#
#                      percentage_AveragePrice  cumsum_pct
# region
# HartfordSpringfield                 0.024378    0.024378
# SanFrancisco                        0.024184    0.048562
# NewYork                             0.023157    0.071719
# Philadelphia                        0.021878    0.093597
# Sacramento                          0.021736    0.115333

# %%
# visualisasi rata-rata harga alpukat pada setiap region
ax = df_data_group_cat.AveragePrice.plot(kind = 'bar',rot=90,color = 'r')
df_data_group_cat.cumsum_pct.plot(kind='line',
                                  linestyle='-',
                                  marker='o',figsize = (20,10),rot=90,secondary_y=True)
# Out:
# <Axes: >

# %%
# Pareto Chart menggunakan plotly
fig = go.Figure()

fig.add_trace(
    go.Bar(
        x= df_data_group_cat["region"],
        y= df_data_group_cat["AveragePrice"],
        name="Bar Chart"
    ))

fig.add_trace(
    go.Scatter(
        x= df_data_group_cat["region"],
        y= df_data_group_cat["cumsum_pct"]*df_data_group_cat["AveragePrice"].max(),
        mode="markers+lines",
        customdata = df_data_group_cat["cumsum_pct"],
        hovertemplate="cumsum_pct : %{customdata}",
        name="Cumulative"
    ))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Rata-rata harga alpukat tertinggi di region Hartford Springfield, San Francisco, dan Newyork.

# %% [markdown]
# ### Tree Map

# %% [markdown]
# Tree map adalah jenis visualisasi yang membantu untuk melihat dan menampilkan informasi hirarkis dalam serangkaian persegi panjang yang berkerumun. Jika data Anda hirarki, Tree map adalah cara yang baik untuk menunjukkan semua nilai sekaligus serta dapat menjaga struktur data dalam bentuk visual

# %%
fig = px.treemap(df, path=[px.Constant('Region'), 'region'], values='Total Volume', color='AveragePrice')
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:1594: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py:1594: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Terlihat dari Tree map di atas, Rata-rata harga alpukat tertinggi terdapat pada region yang memiliki warna kuning yang tinggi, yaitu di region Hartford Springfield, San Francisco, Newyork, dan Philadelphia.

# %% [markdown]
# ### Map

# %% [markdown]
# Visualisasi map digunakan untuk menganalisa dan menampilkan data geografis dan mempresentasikannya dalam bentuk berbagai jenis peta. Data yang diekspresikan melalui visualisasi akan menjadi lebih jelas dan intuitif.

# %%
# menampilkan data
data = pd.read_csv(path_data + 'geolocation.csv')
data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
fig = px.choropleth(data, locations="iso_alpha", color="lifeExp", hover_name="country", animation_frame="year", range_color=[20,80])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data1 = px.data.carshare()
data1
# Out:
#      centroid_lat  centroid_lon    car_hours  peak_hour
# 0       45.471549    -73.588684  1772.750000          2
# 1       45.543865    -73.562456   986.333333         23
# 2       45.487640    -73.642767   354.750000         20
# 3       45.522870    -73.595677   560.166667         23
# 4       45.453971    -73.738946  2836.666667         19
# ..            ...           ...          ...        ...
# 244     45.547171    -73.556258   951.416667          3
# 245     45.546482    -73.574939   795.416667          2
# 246     45.495523    -73.627725   425.750000          8
# 247     45.521199    -73.581789  1044.833333         17
# 248     45.532564    -73.567535   694.916667          5
#
# [249 rows x 4 columns]

# %%
fig = px.scatter_mapbox(data1, lat="centroid_lat", lon="centroid_lon", color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10,
                  mapbox_style="carto-positron")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
